# %%
import gensim
from sklearn.cluster import KMeans
from sklearn.externals import joblib
from time import time

def load_model():
    model = gensim.models.Word2Vec.load("./gensim_moddle/word2vec_gensim")
    return model
